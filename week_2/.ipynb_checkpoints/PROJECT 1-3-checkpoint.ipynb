# %% [markdown]
# # Algorithm to swap the ages
# # of two names
# PRINT "Enter age of name 1"
# PRINT "Enter age of name 2"
# INPUT Name_1
# INPUT Name_2
#
# LET Temp = age
#
# LET Temp = Name_1
# LET Name_1 = Name_2
# LET Name_2 = Temp
# PRINT "The age of Name_1 after swapping is"
# PRINT Name_1
# PRINT "The age of Name_2 after swapping is"
# PRINT Name_2
